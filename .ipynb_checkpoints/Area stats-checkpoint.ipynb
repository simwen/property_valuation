# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json

# %%
r= requests.get('https://www.plumplot.co.uk/London-house-prices.html')
soup = BeautifulSoup(r.text, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
#soup.find_all("td", class_="mh2")
#soup.find_all(lambda tag: tag.name == 'td' and 
#              tag.get('class') == ['mh2'])
rows = soup.find_all("tr")
rows
# Out:
# [<tr><th class="text-left mh2">Price</th><th class="text-center mh2">London <small><small>region</small></small></th><th class="text-right mh2">England &amp; Wales</th></tr>,
#  <tr><td class="mh2 text-left">average</td><td class="mh1"><span class="pr7">&amp;block; </span>£718k</td><td class="mh1 text-right"><span class="pr5">&amp;block; </span>£353k</td></tr>,
#  <tr><td class="mh2 text-left">median</td><td class="mh1"><span class="pr7">&amp;block; </span>£520k</td><td class="mh1 text-right"><span class="pr4">&amp;block; </span>£270k</td></tr>,
#  <tr><th class="mh2" colspan="2">Postcode sector</th><th class="mh2 text-center">Average price </th><th class="mh2 text-right">% of London avg. price (£718k)</th></tr>,
#  <tr><td style="background: #FC4E2A"></td><td class="mh2">BR1 1</td><td class="mh2 text-center">£367k</td><td class="mh2 text-right">51%</td></tr>,
# ...

# %%
outcode, 
for i in range(4,10):
    #print(rows[i])
    print(rows[i].find(lambda tag: tag.name == 'td' and 
              tag.get('class') == ['mh2']).text)
# Out:
# BR1 1
# BR1 2
# BR1 3
# BR1 4
# BR1 5
# BR2 0
